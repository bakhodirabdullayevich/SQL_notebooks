# %% [markdown]
# <a href="https://colab.research.google.com/github/bakhodirabdullayevich/SQL_notebooks/blob/main/SQLite3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('db')

# %%
df = pd.DataFrame({'col':[1,2,3]})

# %%
df
# Out:
#    col
# 0    1
# 1    2
# 2    3

# %%
df.to_sql('test_table', con, index=False, if_exists='replace')
# Out:
# 3

# %%
sql = '''select * from test_table t'''

# %%
print(sql)
# Out:
# select * from test_table t

# %%
pd.read_sql(sql, con)
# Out:
#    col
# 0    1
# 1    2
# 2    3

# %% [markdown]
# Quyidagi Funksiyani yaratib foydalanish mumkin

# %%
def select(sql):
  return pd.read_sql(sql, con)

# %%
select(sql)
# Out:
#    col
# 0    1
# 1    2
# 2    3

# %%
sqlite3.sqlite_version
# Out:
# '3.37.2'

# %%
sql = '''Create table If Not Exists Employee (Id int, Salary int)
insert into Employee (Id, Salary) values ('1', '100')
insert into Employee (Id, Salary) values ('2', '200')
insert into Employee (Id, Salary) values ('3', '300')'''

# %%
sql = ';\n'.join(sql.split('\n'))

# %%
print(sql)
# Out:
# Create table If Not Exists Employee (Id int, Salary int);
# insert into Employee (Id, Salary) values ('1', '100');
# insert into Employee (Id, Salary) values ('2', '200');
# insert into Employee (Id, Salary) values ('3', '300')

# %%
con.executescript(sql)

# %% [markdown]
# '/content/drive/My Drive/data' Google diskda data papka ichida yaratamiz

# %%
# !ls '/content/drive/My Drive/data'
# Out:
# german_credit_augmented.csv  test.db

# %%
con = sqlite3.connect('test.db')

# %% [markdown]
# # **Postgresql**
# [customer.elephantsql.com](https://) - kichik postgresql ma'lumotlar bazasini yaratib foydalanish mumkin
#
#
#
# ```
# from sqlalchemy import create_engine
# con = create_engine('postgresql+psycopg2://........')
# ```

# %%
df = pd.read_csv('/content/drive/My Drive/data/german_credit_augmented.csv')

# %%
df.head()
# Out:
#    age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0   33    male    2     own             NaN              NaN           3074
# 1   43    male    1     own          little           little           1344
# 2   52    male    2     own      quite rich              NaN            936
# 3   35  female    3     own          little              NaN           1393
# 4   28    male    2     own          little              NaN            776
#
#    duration    purpose  default          contract_dt  client_id
# 0         9   radio/TV        0  2008-06-29 18:52:00        210
# 1        12        car        0  2007-05-20 18:30:19        929
# 2         9  education        0  2008-04-27 08:23:07        200
# 3        11        car        0  2007-05-06 10:58:22         45
# 4        12   radio/TV        0  2007-07-21 13:22:14        358

# %%
df.dtypes
# Out:
# age                  int64
# sex                 object
# job                  int64
# housing             object
# saving_accounts     object
# checking_account    object
# credit_amount        int64
# duration             int64
# purpose             object
# default              int64
# contract_dt         object
# client_id            int64
# dtype: object

# %%
df['contract_dt'] = pd.to_datetime(df['contract_dt'], format='%Y-%m-%d %H:%M:%S')

# %%
df.dtypes
# Out:
# age                          int64
# sex                         object
# job                          int64
# housing                     object
# saving_accounts             object
# checking_account            object
# credit_amount                int64
# duration                     int64
# purpose                     object
# default                      int64
# contract_dt         datetime64[ns]
# client_id                    int64
# dtype: object

# %%
def select(sql):
  return pd.read_sql(sql, con)

# %%
con = sqlite3.connect('german_credit')

# %%
df.to_sql('german_credit',con,index=False,if_exists='replace')
# Out:
# 1000

# %%
sql = '''select * from german_credit as t'''

# %%
select(sql)
# Out:
#      age     sex  job housing saving_accounts checking_account  credit_amount  \
# 0     33    male    2     own            None             None           3074
# 1     43    male    1     own          little           little           1344
# 2     52    male    2     own      quite rich             None            936
# 3     35  female    3     own          little             None           1393
# 4     28    male    2     own          little             None            776
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   65    male    2    free          little           little           2600
# 996   30    male    3     own          little         moderate           4455
# 997   33    male    2     own          little         moderate           6403
# 998   29  female    2     own            None             None           5003
# 999   44    male    2     own        moderate         moderate           1804
#
# ...
